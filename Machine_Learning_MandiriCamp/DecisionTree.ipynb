# %% [markdown]
# # DecisionTree

# %%
import pandas as pd

# %%
df1 = pd.read_csv('decisiontree_ch6.csv')
encoding = {"mesin": {"bensin": 0, "diesel": 1}, "penggerak": {"depan": 0, "belakang": 1}}
df1.replace(encoding, inplace=True)
# Out:
# <ipython-input-15-8ae679d2d6b4>:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df1.replace(encoding, inplace=True)

# %%
print(df1)
# Out:
#     ID  mesin  bangku  penggerak    label
# 0    1      0       4          0    sedan
# 1    2      0       2          0    sedan
# 2    3      0       8          1  minibus
# 3    4      1       6          0  minibus
# 4    5      0       5          1  minibus
# 5    6      1       8          1  minibus
# 6    7      1       8          1  minibus
# 7    8      0       4          0    sedan
# 8    9      1       7          1  minibus
# 9   10      0       4          0    sedan
# 10  11      0       2          0    sedan
# 11  12      1       6          1  minibus
# 12  13      1       8          0  minibus
# 13  14      0       4          0    sedan
# 14  15      1       2          0    sedan
# 15  16      0       4          0    sedan
# 16  17      0       8          1  minibus
# 17  18      0       4          0    sedan
# 18  19      1       8          1  minibus
# 19  20      1       8          1  minibus
# 20  21      0       4          0    sedan
# ...

# %%
X = df1.drop(['ID', 'label'], axis=1)
y = df1['label']

# %%
import sklearn.model_selection as ms
X_train, X_test, y_train, y_test = ms.train_test_split(X, y, test_size=0.2)

# %%
import sklearn.tree as tree
model1 = tree.DecisionTreeClassifier(criterion='entropy', max_depth=5)
model1.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5)

# %%
y_pred = model1.predict(X_test)
print(y_pred)
# Out:
# ['minibus' 'minibus' 'sedan' 'minibus' 'minibus' 'minibus' 'sedan' 'sedan']

# %%
import sklearn.metrics as met
print(met.accuracy_score(y_test, y_pred))
# Out:
# 0.875

# %%
import sklearn.tree as tree
import sklearn.metrics as met
model2 = tree.DecisionTreeClassifier(criterion='gini', max_depth=5)
model2.fit(X_train, y_train)
y_pred = model2.predict(X_test)
print(y_pred)
print(met.accuracy_score(y_test, y_pred))
# Out:
# ['sedan' 'minibus' 'sedan' 'minibus' 'minibus' 'minibus' 'sedan' 'sedan']
# 1.0

# %% [markdown]
# # RandomForest

# %%
import sklearn.ensemble as ens
rf = ens.RandomForestClassifier(n_estimators=100)

# %%
import pandas as pd
import sklearn.model_selection as ms
dfraf = pd.read_csv('decisiontree_ch6.csv')
encoding = {"mesin": {"bensin": 0, "diesel": 1}, "penggerak": {"depan": 0, "belakang": 1}}
dfraf.replace(encoding, inplace=True)
print(dfraf)
X = dfraf.drop(['ID', 'label'], axis=1)
y = dfraf['label']
X_train, X_test, y_train, y_test = ms.train_test_split(X, y, test_size=0.2)
# Out:
#     ID  mesin  bangku  penggerak    label
# 0    1      0       4          0    sedan
# 1    2      0       2          0    sedan
# 2    3      0       8          1  minibus
# 3    4      1       6          0  minibus
# 4    5      0       5          1  minibus
# 5    6      1       8          1  minibus
# 6    7      1       8          1  minibus
# 7    8      0       4          0    sedan
# 8    9      1       7          1  minibus
# 9   10      0       4          0    sedan
# 10  11      0       2          0    sedan
# 11  12      1       6          1  minibus
# 12  13      1       8          0  minibus
# 13  14      0       4          0    sedan
# 14  15      1       2          0    sedan
# 15  16      0       4          0    sedan
# 16  17      0       8          1  minibus
# 17  18      0       4          0    sedan
# 18  19      1       8          1  minibus
# 19  20      1       8          1  minibus
# 20  21      0       4          0    sedan
# ...

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
print(rf)
# Out:
# RandomForestClassifier()

# %%
y_prediksi = rf.predict(X_test)
print(y_prediksi)
# Out:
# ['minibus' 'sedan' 'minibus' 'sedan' 'sedan' 'sedan' 'minibus' 'minibus']

# %%
import sklearn.metrics as met
print(met.accuracy_score(y_test, y_prediksi))
# Out:
# 1.0

# %%
print(rf.feature_importances_)
# Out:
# [0.22966024 0.4473191  0.32302066]

# %%
import pandas as pd
import numpy as np
import sklearn.tree as tree
import sklearn.model_selection as ms
import sklearn.ensemble as ens
import sklearn.metrics as met
rf = ens.RandomForestClassifier(n_estimators=100)
data = pd.read_csv('bab6_adult_data.csv')

# %%
data.head(10)
# Out:
#    age          workclass  fnlwft   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
# 5   37            Private  284582     Masters             14
# 6   49            Private  160187         9th              5
# 7   52   Self-emp-not-inc  209642     HS-grad              9
# 8   31            Private   45781     Masters             14
# 9   42            Private  159449   Bachelors             13
#
#            marital_status          occupation    relationship    race  \
# 0           Never-married        Adm-clerical   Not-in-family   White
# 1      Married-civ-spouse     Exec-managerial         Husband   White
# 2                Divorced   Handlers-cleaners   Not-in-family   White
# ...

# %%
data.dropna(inplace=True)

# %%
import sklearn.preprocessing as prep
gender = prep.LabelEncoder()
gender.fit(data['sex'])
data['sex_code'] = gender.transform(data['sex'])
data[['sex', 'sex_code']].head(5)
# Out:
#        sex  sex_code
# 0     Male         1
# 1     Male         1
# 2     Male         1
# 3     Male         1
# 4   Female         0

# %%
education = prep.LabelEncoder()
education.fit(data['education'])
data['education_code'] = education.transform(data['education'])

race = prep.LabelEncoder()
race.fit(data['race'])
data['race_code'] = race.transform(data['race'])

workclass = prep.LabelEncoder()
workclass.fit(data['workclass'])
data['workclass_code'] = workclass.transform(data['workclass'])

occupation = prep.LabelEncoder()
occupation.fit(data['occupation'])
data['occupation_code'] = occupation.transform(data['occupation'])

relationship = prep.LabelEncoder()
relationship.fit(data['relationship'])
data['relationship_code'] = relationship.transform(data['relationship'])

native_country = prep.LabelEncoder()
native_country.fit(data['native_country'])
data['native_country_code'] = native_country.transform(data['native_country'])

# %%
X = data.drop(['fnlwft','workclass', 'education', 'marital_status', 'occupation', 'relationship', 'race', 'sex', 'native_country', 'income'], axis=1)
y = data['income']

# %%
X_train, X_test, y_train, y_test = ms.train_test_split(X, y, test_size=0.2)

# %%
rf.fit(X_train, y_train)
y_prediksi = rf.predict(X_test)
print('akurasi = ', met.accuracy_score(y_test, y_prediksi))
print(met.classification_report(y_test, y_prediksi))
print(rf.feature_importances_)
# Out:
# akurasi =  0.5043504964684206
#               precision    recall  f1-score   support
#
#        <=50K       0.59      0.72      0.65      4951
#       <=50K.       0.29      0.18      0.22      2464
#         >50K       0.48      0.50      0.49      1577
#        >50K.       0.20      0.12      0.15       777
#
#     accuracy                           0.50      9769
#    macro avg       0.39      0.38      0.38      9769
# weighted avg       0.47      0.50      0.48      9769
#
# [0.29580907 0.06129479 0.0617042  0.02663597 0.15736047 0.01596607
#  0.03954838 0.03331132 0.06749124 0.12550919 0.080472   0.0348973 ]
